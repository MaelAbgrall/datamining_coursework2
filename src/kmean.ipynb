# %%
# %matplotlib inline

# %%
import os
import time
import sys
import utils.learning as lrn

# libs
import matplotlib
import matplotlib.pyplot as plt
import sklearn.cluster as skcluster
import numpy

# project files
import utils.filehandler as filehandler
import view.plot as viewer

# %%
# debug mode: python main.py -d
DEBUG = True

# defining hyperparameters
Kcluster = 7 # there is 7 emotions

# import data
dataset = filehandler.import_csv('../fer2018/fer2018.csv')
(x_train, y_train, x_validation, y_validation) = filehandler.classic_split(dataset, 0.75)

# dictionary to save and compare accuracy for different amounts of attributes
acc_dct = {}
# Out:
# importing ../fer2018/fer2018.csv
# F:\Code_ecole\datamining\datamining_coursework2\src\utils\filehandler.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data = data_frame.as_matrix()
# importation done in: 12.129674434661865

# %%
# Classifier initialization
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=800, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n900")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=900, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1000")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=1000, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1100")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=1100, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1200")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=1200, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1300")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=1300, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)

# Classifier initialization
print("\n\n1400")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='k-means++', n_init=10, max_iter=1400, verbose=1)
preds = lrn.get_preds(kmean, x_train, x_validation)
# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)
# Out:
# Fitting data...
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 177371226061.1262
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 172402815399.7451
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 170465323005.97055
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 169015962774.6079
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 167997195963.16034
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 167317890316.18155
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 166897641442.08914
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 166606762880.29456
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 166396651513.9709
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 166230803219.278
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 166109549845.76917
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 166025329106.24457
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 165963418580.5064
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 165910155184.09875
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 165857202332.12094
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 165814154488.09912
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 165769871809.43362
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 165722508958.96
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 165671043456.2571
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 165626001135.06094
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 165585427430.7326
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 165541240808.1203
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 165496800531.6684
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 165452535699.9044
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 165403539445.08447
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 165355995028.97397
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 165312069196.03696
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 165266083381.06415
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 165220905788.2142
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 165186205427.2556
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 165152465564.26843
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 165120091601.22772
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 165089075117.67334
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 165058282034.54984
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 165031812289.84702
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 165008316006.24725
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 164985497883.556
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 164963203691.289
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 164942451360.47385
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 164925957377.5133
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 164911755434.31174
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 164900458596.0324
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 164889052825.3672
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 164875992909.84238
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 164861272802.1347
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 164850525254.13232
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 164841207984.80798
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 164832308293.63248
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 164822328082.07364
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 164814273047.37292
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 164807208118.9072
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 164801219950.84024
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 164795696264.00708
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 164791390067.21753
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 164787217978.15497
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 164783791591.0401
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 164780738829.42612
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 164778637400.46008
# start iteration
# done sorting
# end inner loop
# Iteration 58, inertia 164775700301.52744
# start iteration
# done sorting
# end inner loop
# Iteration 59, inertia 164772555327.61957
# start iteration
# done sorting
# end inner loop
# Iteration 60, inertia 164769064364.15973
# start iteration
# done sorting
# end inner loop
# Iteration 61, inertia
# Iteration 67, inertia 165136215334.11008
# start iteration
# done sorting
# end inner loop
# Iteration 68, inertia 165134398763.358
# start iteration
# done sorting
# end inner loop
# Iteration 69, inertia 165132801599.03055
# start iteration
# done sorting
# end inner loop
# Iteration 70, inertia 165131503501.60333
# start iteration
# done sorting
# end inner loop
# Iteration 71, inertia 165130165704.5589
# start iteration
# done sorting
# end inner loop
# Iteration 72, inertia 165128515300.20932
# start iteration
# done sorting
# end inner loop
# Iteration 73, inertia 165126865289.9139
# start iteration
# done sorting
# end inner loop
# Iteration 74, inertia 165124953094.77487
# start iteration
# done sorting
# end inner loop
# Iteration 75, inertia 165122769013.36658
# start iteration
# done sorting
# end inner loop
# Iteration 76, inertia 165120305458.83774
# start iteration
# done sorting
# end inner loop
# Iteration 77, inertia 165117023426.46783
# start iteration
# done sorting
# end inner loop
# Iteration 78, inertia 165113297162.68484
# start iteration
# done sorting
# end inner loop
# Iteration 79, inertia 165109395354.35324
# start iteration
# done sorting
# end inner loop
# Iteration 80, inertia 165105149792.37726
# start iteration
# done sorting
# end inner loop
# Iteration 81, inertia 165101612468.8115
# start iteration
# done sorting
# end inner loop
# Iteration 82, inertia 165097749673.41263
# start iteration
# done sorting
# end inner loop
# Iteration 83, inertia 165090913029.52283
# start iteration
# done sorting
# end inner loop
# Iteration 84, inertia 165081756583.30185
# start iteration
# done sorting
# end inner loop
# Iteration 85, inertia 165070695027.51028
# start iteration
# done sorting
# end inner loop
# Iteration 86, inertia 165061061663.79443
# start iteration
# done sorting
# end inner loop
# Iteration 87, inertia 165049946982.12793
# start iteration
# done sorting
# end inner loop
# Iteration 88, inertia 165040781071.9494
# start iteration
# done sorting
# end inner loop
# Iteration 89, inertia 165028661545.80682
# start iteration
# done sorting
# end inner loop
# Iteration 90, inertia 165016488163.91928
# start iteration
# done sorting
# end inner loop
# Iteration 91, inertia 165002782254.90433
# start iteration
# done sorting
# end inner loop
# Iteration 92, inertia 164989144070.54102
# start iteration
# done sorting
# end inner loop
# Iteration 93, inertia 164976847941.0629
# start iteration
# done sorting
# end inner loop
# Iteration 94, inertia 164964829465.9324
# start iteration
# done sorting
# end inner loop
# Iteration 95, inertia 164952489171.9802
# start iteration
# done sorting
# end inner loop
# Iteration 96, inertia 164941469788.51584
# start iteration
# done sorting
# end inner loop
# Iteration 97, inertia 164930493765.95032
# start iteration
# done sorting
# end inner loop
# Iteration 98, inertia 164918705280.77954
# start iteration
# done sorting
# end inner loop
# Iteration 99, inertia 164908375382.98447
# start iteration
# done sorting
# end inner loop
# Iteration 100, inertia 164898099598.26068
# start iteration
# done sorting
# end inner loop
# Iteration 101, inertia 164886739092.51218
# start iteration
# done sorting
# end inner loop
# Iteration 102, inertia 164876521611.0361
# start iteration
# done sorting
# end inner loop
# Iteration 103, inertia 164868658163.301
# start iteration
# done sorting
# end inner loop
# Iteration 104, inertia 164860839025.17075
# start iteration
# done sorting
# end inner loop
# Iteration 105, inertia 164852710122.15533
# start iteration
# done sorting
# end inner loop
# Iteration 106, inertia 164844879163.83942
# start iteration
# done sorting
# end inner loop
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 165363536807.48068
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 165191099497.18726
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 165058773508.06418
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 164958707367.39795
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 164888134716.20914
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 164841810323.28357
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 164803905784.2265
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 164773129527.92688
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 164752730182.47775
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 164741514628.61868
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 164735748467.199
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 164730661617.57904
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 164725628039.67218
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 164721630666.94952
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 164717271219.21725
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 164713088192.2867
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 164709666930.6554
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 164706739890.63434
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 164703830867.33786
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 164701340822.7589
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 164699274096.46066
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 164697234010.6981
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 164695376186.93292
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 164694194771.22656
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 164693455214.98312
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 164692812898.5644
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 164692109906.45816
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 164691238335.9474
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 164690574264.7016
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 164689820233.10287
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 164688973260.0723
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 164688289885.05438
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 164687970195.70804
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 164687690933.4838
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 164687432901.77466
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 164687180168.02975
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 164686986507.80725
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 164686906384.09735
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 164686723750.40353
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 164686584427.99655
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 164686520374.6135
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 164686444864.90906
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 164686417064.8064
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 164686412214.5883
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 164686412214.5883
# center shift 0.000000e+00 within tolerance 4.006888e-01
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 185811332784.2616
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 172844098068.14673
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 169717003570.9124
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 168073470556.98105
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 167070208698.8383
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 166486615000.63998
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 166142093482.89966
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 165905173504.80508
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 165741193750.62427
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 165635432872.5673
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 165558341299.87225
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 165501999517.3198
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 165465335489.1239
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 165439397510.288
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 165417687745.3041
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 165401811508.56107
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 165391044286.81604
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 165384144162.41962
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 165378442711.01736
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 165374091124.94724
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 165369093636.1143
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 165363348885.1785
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 165357080718.82776
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 165348932461.428
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 165336537166.78186
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 165323778437.5729
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 165309119672.81992
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 165293359620.04245
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 165273846707.29657
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 165250166300.54236
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 165225430843.3255
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 165200887198.3729
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 165176644719.10318
# start iteration
# done sorting
# end inner loop

# %%
# Classifier initialization
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=800)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n900")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=900)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1000")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=1000)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1100")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=1100)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1200")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=1200)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)


# Classifier initialization
print("\n\n1300")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=1300)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)

# Classifier initialization
print("\n\n1400")
kmean = skcluster.KMeans(n_clusters=Kcluster, init='random', n_init=10, max_iter=1400)
preds = lrn.get_preds(kmean, x_train, x_validation)

# classification accuracy calculation
viewer.overall_accuracy(acc_dct, '2304', preds, y_validation)
viewer.accuracy_plots('2304', preds, y_validation)
# Out:
# Fitting data...
# 135.76706337928772 seconds to fit data
# Making predictions...
# 0.1984694004058838 seconds to predict the classes
# 1185 out of 8971
# 13.209% correctly predicted
# 900
# Fitting data...
# 147.513662815094 seconds to fit data
# Making predictions...
# 0.2014608383178711 seconds to predict the classes
# 1247 out of 8971
# 13.900% correctly predicted
# 1000
# Fitting data...
# 144.97541785240173 seconds to fit data
# Making predictions...
# 0.2214066982269287 seconds to predict the classes
# 1303 out of 8971
# 14.525% correctly predicted
# 1100
# Fitting data...
# 134.72784638404846 seconds to fit data
# Making predictions...
# 0.19846773147583008 seconds to predict the classes
# 1606 out of 8971
# 17.902% correctly predicted
# 1200
# Fitting data...
# 139.01640725135803 seconds to fit data
# Making predictions...
# 0.20444822311401367 seconds to predict the classes
# 1345 out of 8971
# 14.993% correctly predicted
# 1300
# Fitting data...
# 108.21867990493774 seconds to fit data
# Making predictions...
# 0.19647455215454102 seconds to predict the classes
# 1276 out of 8971
# 14.224% correctly predicted
# 1400
# Fitting data...
# 150.8876438140869 seconds to fit data
# Making predictions...
# 0.2094402313232422 seconds to predict the classes
# 1203 out of 8971
# 13.410% correctly predicted

# %%
# Importing data from each individual emotion file
angryset = filehandler.import_csv('../fer2018/fer2018angry.csv')
(x_angry, y_angry, _, _) = filehandler.classic_split(angryset, 100)

disgustset = filehandler.import_csv('../fer2018/fer2018disgust.csv')
(x_disgust, y_disgust, _, _) = filehandler.classic_split(disgustset, 100)

fearset = filehandler.import_csv('../fer2018/fer2018fear.csv')
(x_fear, y_fear, _, _) = filehandler.classic_split(fearset, 100)

happyset = filehandler.import_csv('../fer2018/fer2018happy.csv')
(x_happy, y_happy, _, _) = filehandler.classic_split(happyset, 100)

sadset = filehandler.import_csv('../fer2018/fer2018sad.csv')
(x_sad, y_sad, _, _) = filehandler.classic_split(sadset, 100)

surpriseset = filehandler.import_csv('../fer2018/fer2018surprise.csv')
(x_surprise, y_surprise, _, _) = filehandler.classic_split(surpriseset, 100)

neutralset = filehandler.import_csv('../fer2018/fer2018neutral.csv')
(x_neutral, y_neutral, _, _) = filehandler.classic_split(neutralset, 100)
# Out:
# importing ../fer2018/fer2018angry.csv
# F:\Code_ecole\datamining\datamining_coursework2\src\utils\filehandler.py:21: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data = data_frame.as_matrix()
# importation done in: 12.231325387954712
# importing ../fer2018/fer2018disgust.csv
#
# importation done in: 12.173457622528076
# importing ../fer2018/fer2018fear.csv
#
# importation done in: 12.147525548934937
# importing ../fer2018/fer2018happy.csv
#
# importation done in: 12.108652591705322
# importing ../fer2018/fer2018sad.csv
#
# importation done in: 12.302300453186035
# importing ../fer2018/fer2018surprise.csv
#
# importation done in: 12.18842077255249
# importing ../fer2018/fer2018neutral.csv
#
# importation done in: 12.11059832572937

# %%
"""
BEST FEATURE COLLECTION
"""

# Search for top TEN attributes for each emotion
print("Searching for top 10 attributes...")
x_angry_10 = lrn.get_k_best(x_angry, y_angry, 10)
x_disgust_10 = lrn.get_k_best(x_disgust, y_disgust, 10)
x_fear_10 = lrn.get_k_best(x_fear, y_fear, 10)
x_happy_10 = lrn.get_k_best(x_happy, y_happy, 10)
x_sad_10 = lrn.get_k_best(x_sad, y_sad, 10)
x_surprise_10 = lrn.get_k_best(x_surprise, y_surprise, 10)
x_neutral_10 = lrn.get_k_best(x_neutral, y_neutral, 10)

# Search for top FIVE attributes for each emotion
print("Searching for top 5 attributes...")
x_angry_5 = lrn.get_k_best(x_angry, y_angry, 5)
x_disgust_5 = lrn.get_k_best(x_disgust, y_disgust, 5)
x_fear_5 = lrn.get_k_best(x_fear, y_fear, 5)
x_happy_5 = lrn.get_k_best(x_happy, y_happy, 5)
x_sad_5 = lrn.get_k_best(x_sad, y_sad, 5)
x_surprise_5 = lrn.get_k_best(x_surprise, y_surprise, 5)
x_neutral_5 = lrn.get_k_best(x_neutral, y_neutral, 5)

# Search for top TWO attributes for each emotion
print("Searching for top 2 attributes...")
x_angry_2 = lrn.get_k_best(x_angry, y_angry, 2)
x_disgust_2 = lrn.get_k_best(x_disgust, y_disgust, 2)
x_fear_2 = lrn.get_k_best(x_fear, y_fear, 2)
x_happy_2 = lrn.get_k_best(x_happy, y_happy, 2)
x_sad_2 = lrn.get_k_best(x_sad, y_sad, 2)
x_surprise_2 = lrn.get_k_best(x_surprise, y_surprise, 2)
x_neutral_2 = lrn.get_k_best(x_neutral, y_neutral, 2)
# Out:
# Searching for top 10 attributes...
# Searching for top 5 attributes...
# Searching for top 2 attributes...

# %%
"""
DATASET REDUCTION
"""
# 14, 35, and 70 non-class attribute reduction:
top_attrs = {2 : numpy.array([x_angry_2, x_disgust_2, x_fear_2, x_happy_2, x_sad_2, x_surprise_2, x_neutral_2]).flatten(),
        5 : numpy.array([x_angry_5, x_disgust_5, x_fear_5, x_happy_5, x_sad_5, x_surprise_5, x_neutral_5]).flatten(),
        10 : numpy.array([x_angry_10, x_disgust_10, x_fear_10, x_happy_10, x_sad_10, x_surprise_10, x_neutral_10]).flatten()}

print("\nReducing datasets...")
x_train_70 = lrn.reduce_attr(x_train, top_attrs[10])
x_train_35 = lrn.reduce_attr(x_train, top_attrs[5])
x_train_14 = lrn.reduce_attr(x_train, top_attrs[2])
x_validation_70 = lrn.reduce_attr(x_validation, top_attrs[10])
x_validation_35 = lrn.reduce_attr(x_validation, top_attrs[5])
x_validation_14 = lrn.reduce_attr(x_validation, top_attrs[2])
# Out:
# Reducing datasets...

# %%
"""
ATTEMPT TO IMPROVE CLASSIFICATION WITH NEW DATASETS
"""
print("\n70 attribute classification")
preds = lrn.get_preds(kmean, x_train_70, x_validation_70)
viewer.overall_accuracy(acc_dct, '70', preds, y_validation)
viewer.accuracy_plots('70', preds, y_validation)

print("\n35 attribute classification")
preds = lrn.get_preds(kmean, x_train_35, x_validation_35)
viewer.overall_accuracy(acc_dct, '35', preds, y_validation)
viewer.accuracy_plots('35', preds, y_validation)

print("\n14 attribute classification")
preds = lrn.get_preds(kmean, x_train_14, x_validation_14)
viewer.overall_accuracy(acc_dct, '14', preds, y_validation)
viewer.accuracy_plots('14', preds, y_validation)
# Out:
# 70 attribute classification
# Fitting data...
# 4.686494588851929 seconds to fit data
# Making predictions...
# 0.04285717010498047 seconds to predict the classes
# 1392 out of 8971
# 15.517% correctly predicted
# 35 attribute classification
# Fitting data...
# 3.830806016921997 seconds to fit data
# Making predictions...
# 0.021968364715576172 seconds to predict the classes
# 1171 out of 8971
# 13.053% correctly predicted
# 14 attribute classification
# Fitting data...
# 2.738678216934204 seconds to fit data
# Making predictions...
# 0.012967586517333984 seconds to predict the classes
# 1343 out of 8971
# 14.970% correctly predicted

# %%
"""
DATASET REDUCTION BASED ON CLASS
"""
# 2, 5, and 10 non-class attribute reduction:
# the top attributes of each specific emotion
top_attrs_emo = {2 : [x_angry_2, x_disgust_2, x_fear_2, x_happy_2, x_sad_2, x_surprise_2, x_neutral_2],
                5 : [x_angry_5, x_disgust_5, x_fear_5, x_happy_5, x_sad_5, x_surprise_5, x_neutral_5],
                10 : [x_angry_10, x_disgust_10, x_fear_10, x_happy_10, x_sad_10, x_surprise_10, x_neutral_10]}

# transforming the overall emotion dataset
x_train_10 = lrn.reduce_data_emo(top_attrs_emo, x_train, y_train, 10)
x_train_5 = lrn.reduce_data_emo(top_attrs_emo, x_train, y_train, 5)
x_train_2 = lrn.reduce_data_emo(top_attrs_emo, x_train, y_train, 2)
x_validation_10 = lrn.reduce_data_emo(top_attrs_emo, x_validation, y_validation, 10)
x_validation_5 = lrn.reduce_data_emo(top_attrs_emo, x_validation, y_validation, 5)
x_validation_2 = lrn.reduce_data_emo(top_attrs_emo, x_validation, y_validation, 2)

# %%
"""
2nd ATTEMPT TO IMPROVE CLASSIFICATION WITH NEW DATASETS
"""
print("\n10 attribute classification")
preds = lrn.get_preds(kmean, x_train_10, x_validation_10)
viewer.overall_accuracy(acc_dct, '10', preds, y_validation)
viewer.accuracy_plots('10', preds, y_validation)

print("\n5 attribute classification")
preds = lrn.get_preds(kmean, x_train_5, x_validation_5)
viewer.overall_accuracy(acc_dct, '5', preds, y_validation)
viewer.accuracy_plots('5', preds, y_validation)

print("\n2 attribute classification")
preds = lrn.get_preds(kmean, x_train_2, x_validation_2)
viewer.overall_accuracy(acc_dct, '2', preds, y_validation)
viewer.accuracy_plots('2', preds, y_validation)
# Out:
# 10 attribute classification
# Fitting data...
# 2.322747230529785 seconds to fit data
# Making predictions...
# 0.00899815559387207 seconds to predict the classes
# 1308 out of 8971
# 14.580% correctly predicted
# 5 attribute classification
# Fitting data...
# 1.7336068153381348 seconds to fit data
# Making predictions...
# 0.007953643798828125 seconds to predict the classes
# 1517 out of 8971
# 16.910% correctly predicted
# 2 attribute classification
# Fitting data...
# 0.9868066310882568 seconds to fit data
# Making predictions...
# 0.0049893856048583984 seconds to predict the classes
# 1555 out of 8971
# 17.334% correctly predicted

# %%
"""
ACCURACY SUMMARY
"""
viewer.disp_acc_summary(acc_dct)

# %%
# feedback
path = None #in case of debug
if(DEBUG == False):
    path = "result/test_" + str(time.time())
    os.makedirs(path, exist_ok=True)
    #plt.plot(val_loss, label="validation loss")
    #plt.plot(loss, label="train loss")
    #plt.title('Loss evolution')
    #plt.ylabel('Loss')
    #plt.xlabel('Iterations')
    #plt.savefig(path + "loss.png")
